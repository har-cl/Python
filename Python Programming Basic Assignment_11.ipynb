# %%
print('Write a Python program to find words which are greater than given length k?')

n=int(input('Enter no of elements in array : '))
l=[]
for i in range(0,n):
    e=input('enter element : ')
    l.append(e)
print('Entered array is : ',l)
k=int(input('Enter lengh above which elements are required : '))
print('Required elements are : ')
for i in l:
    if len(i)>k:
        print(i)

print('Write a Python program for removing i-th character from a string?')

s=input('Enter string : ')
i=int(input('Enter value of i, which character you want to remove'))

count=0
l1=''
for j in s:
    count+=1
    if count==i:
        pass
    else:
        l1+=j
print('Reuired string is : ',l1)

print('Write a Python program to split and join a string?')

s=input('Enter string : ')
l=[]
s=s+' '
temp=''
for i in s:
    if i!=' ':
        temp+=i
    else:
        l.append(temp)
        temp=''
print('Required split is : ',l)

sj=''
for i in l:
    sj+=i
print(sj)
print('joined string is : ', sj)

print('Write a Python to check if a given string is binary string or not?')

s=input('Enter string : ')
b=1
for i in s:
    if i=='0' or i=='1':
        pass
    else:
        b=0
if b==1:
    print('Entered string is binary')
else:
    print('Entered string is not binary')
    
print('Write a Python program to find uncommon words from two Strings?')

s1=input('Enter string 1 : ')
s2=input('Enter string 2 : ')
s=''
r=''
for i in s1:
    if i in s2 or i in s:
        pass
    else:
        s+=i
for i in s2:
    if i in s1 or i in s:
        pass
    else:
        s+=i
print('Uncommon words are : ', s)

print('Write a Python to find all duplicate characters in string?')

s=input('Enter string 1 : ')

s1=''

for i in s:
    if s.count(i)>1:
        if i not in s1:
            s1+=i

print('Uncommon words are : ', s1)

print('Write a Python Program to check if a string contains any special character?')

s=input('Enter string 1 : ')

s1=''
sc='~!@#$%^&{}[]\<>/?:'
result=0
for i in s:
    if i in sc:
        result=1
if result==1:
    print('It contains special character ')
