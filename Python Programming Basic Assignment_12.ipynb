# %%
print('Write a Python program to Extract Unique dictionary values?')

d={1:'one',2:'two',3:'three','I':'one'}
print('Entered dict is : ',d)
l=d.values()
s=set(l)
l=list(s)
print('Unique values are : ',l)



print('\nWrite a Python program to find the sum of all items in a dictionary?')

d={1:'one',2:'two',3:340,'I':'one'}
dk=d.keys()
dv=d.values()
sum=0
print(dk,dv)
for i in dk:
    if type(i)==int:
        sum+=i
for i in dv:
    if type(i)==int:
        sum+=i
print('Sum of all item is : ',sum)



print('\nWrite a Python program to Merging two Dictionaries?')

d1={1:'one',2:'two',3:340,'I':'one'}
d2={4:'four',5:'five',6:640,'IV':'four'}

for i in d1:
    d[i]=d1[i]
for i in d2:
    d[i]=d2[i]
print('Dict 1 is : ',d1)
print('Dict 2 is : ',d2)
print('Megrged dict is : ',d)



print('\nWrite a Python program to convert key-values list to flat dictionary?')

d={'month':[1, 2, 3],
   'name':['Jan', 'Feb', 'March']}

d1={}

l1=d[list(d.keys())[0]]
l2=d[list(d.keys())[1]]

for i in range(0,len(l1)):
    d1[l1[i]]=l2[i]
print('Megrged dict is : ',d1)



print('\nWrite a Python program to insertion at the beginning in OrderedDict?')

from collections import OrderedDict
d=OrderedDict([(2,'two'),(3,'three')])
print('entered dict is : ',d)
d.update({1:'one'})
d.move_to_end(1,False)

print('Dict after insertion is : ',d)



print('\nWrite a Python program to check order of character in string using OrderedDict()?')

from collections import OrderedDict
w='harshil'
cw='rsh'
l=0
result=0

d=OrderedDict.fromkeys(w)

for key,valve in d.items():
    if (key==cw[l]):
        l+=1
    if (l==len(cw)):
        result=1
        break
if result==1:
    print('Check word is in order of word')
else:
    print('Check word is not in order of word')
    
    
print('\nWrite a Python program to sort Python Dictionaries by Key or Value?')

from collections import OrderedDict
d={1:'one',5:'five',3:'three',4:'four'}
print('entered dict is : ',d)
d1=sorted(d.keys())
d2=OrderedDict()
for i in d1:
    print(i,d[i])
    d2[i]=d[i]
print('Dict after insertion is : ',d2)
