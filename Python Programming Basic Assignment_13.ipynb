# %%
print('Question 1: Write a program that calculates and prints the value according to the given formula: \nQ = Square root of [(2 * C * D)/H] \nFollowing are the fixed values of C and H:\nC is 50. H is 30.')

def fun_q(*args):
    c=50
    h=30
    for i in args:
        result=round(math.sqrt(((2*c*i)/h)))
        print('answer is : ',result)

fun_q(100,150,180)



print('\nQuestion 2: Write a program which takes 2 digits, X,Y as input and generates a 2-dimensional array. The element value in the i-th row and j-th column of the array should be i*j.')

x=int(input('enter digit one : '))
y=int(input('enter digit two : '))
l=[]
for i in range(0,x):
    for j in range(0,y):
        a=i*j
        l.append(a)
    print(l)
    l=[]



print('\nQuestion 3: Write a program that accepts a comma separated sequence of words as input and prints the words in a comma-separated sequence after sorting them alphabetically.')

w=input('Enter words seperated by comma(,) :')
print('entered words are : \n',w)
for i in sorted(w.split(',')):
    print(i,'',end='')
    
    
    
print('\nQuestion 4:Write a program that accepts a sequence of whitespace separated words as input and prints the words after removing all duplicate words and sorting them alphanumerically.')

w=input('Enter words seperated by space :')
print('entered words are : \n',w)
print('\nResult : ')
for i in sorted(list(set(w.split(' ')))):
    print(i,',',end='')
    
    
    
print('\nQuestion 5: Write a program that accepts a sentence and calculate the number of letters and digits.')

w=input('Enter sentence :')
n=0
a=0

for i in w:
    if i.isnumeric()==True:
        n+=1
    elif i.isalpha()==True:
        a+=1

print('LETTERS ',a)
print('DIGITS ',n)



print('\nQuestion 6: A website requires the users to input username and password to register. Write a program to check the validity of password input by users.')

wa=input('Enter passwords seperated by comma(,) :')
ws=wa.split(',')
for w in ws:
    n=0
    a=0
    c1,c2,c3,c4,c5=0,0,0,0,0
    c4_c='$#@'
    l=0

    for i in w:
        if i.islower()==True:
            c1=1
        elif i.isnumeric()==True:
            c2=1
        elif i.isupper()==True:
            c3=1
        elif i in c4_c:
            c4=1
        l+=1

    if c1==1 and c2==1 and c3==1 and c4==1 and l>5 and l<13:
        print(w)
